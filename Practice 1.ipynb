# %%
print("Hello World")
# Out:
# Hello World

# %%
c=float(input("Enter Temperture in Celsius: "))
f=c*9/5+32
print("Temperture in Fahrenheit: ",f)
# Out:
# Enter Temperture in Celsius:  38
# Temperture in Fahrenheit:  100.4

# %%
number = 10
number_2 = 20

print(f"Number Before: {number} and {number_2}")

temp = number
number = number_2
number_2 = temp

print(f"Number After: {number} and {number_2}")
# Out:
# Number Before: 10 and 20
# Number After: 20 and 10

# %%
P=float(input("Enter the value of P: "))
R=float(input("Enter the value of R: "))
T=float(input("Enter the value of T: "))
SI=(P*R*T)/100
print("SI Unit: ",SI)
# Out:
# Enter the value of P:  83.223
# Enter the value of R:  2.43
# Enter the value of T:  22.122
# SI Unit:  44.737738705800005

# %%
number=int(input("Enter the Value: "))
if number%2==0:
           print("Even")
else:
           print("Odd")
# Out:
# Enter the Value:  6
# Even

# %%
length=float(input("Enter the Lenght: "))
width=float(input("Enter the Width: "))
area=length*width
perimeter=2*(length+width)
print("Area: ",area)
print("Perimeter: ",perimeter)
# Out:
# Enter the Lenght:  32.33
# Enter the Width:  23.23
# Area:  751.0259
# Perimeter:  111.12

# %%
number = int(input("Enter the Number: "))
number_2 = int(input("Enter the 2nd Number: "))
number_3 = int(input("Enter the 3rd Number: "))

if number > number_2 and number > number_3:
    print("Number 1 is largest:", number)

elif number_2 > number and number_2 > number_3:
    print("Number 2 is largest:", number_2)

else:
    print("Number 3 is largest:", number_3)
# Out:
# Enter the Number:  5
# Enter the 2nd Number:  3
# Enter the 3rd Number:  9
# Number 3 is largest: 9

# %%
grade=int(input("Enter the Marks: "))
if grade>=100: 
    print("A")
elif grade>=89 and grade<=80: 
    print("B")
elif grade>=79 and grade<=70: 
    print("C")
elif grade>=69 and grade<=60: 
    print("D")
else: 
    print("F")
# Out:
# Enter the Marks:  100
# A

# %%
year=int(input("Enter the Year: "))
if year%4==0: 
    print(f"{year} is a Leap Year.")
# Out:
# Enter the Year:  2024
# 2024 is a Leap Year.

# %%
number=float(input("Enter the Number: "))
number_2=float(input("Enter the Second Number: "))
operator=input("Enter the Value: ")
if operator=="+":
    add=number+number_2
    print(f"{number} {operator} {number_2}: {add}")
elif operator=="-":
    sub=number-number_2
    print(f"{number} {operator} {number_2}: {sub}")
elif operator=="*":
    mul=numbe*number_2
    print(f"{number} {operator} {number_2}: {mul}")
elif operator=="/":
    div=number/number_2
    print(f"{number} {operator} {number_2}: {div}")
elif operator=="%":
    mod=number%number_2
    print(f"{number} {operator} {number_2}: {mod}")
elif operator=="**":
    expo=number**number_2
    print(f"{number} {operator} {number_2}: {expo}")
else: 
    print("Invalid Operation")
# Out:
# Enter the Number:  5
# Enter the Second Number:  2
# Enter the Value:  /
# 5.0 / 2.0: 2.5

# %%
side = float(input("Enter Side 1 of Triangle: "))
side_2 = float(input("Enter Side 2 of Triangle: "))
side_3 = float(input("Enter Side 3 of Triangle: "))

if side + side_2 > side_3 and side + side_3 > side_2 and side_2 + side_3 > side:
    print("These sides can form a triangle.")
else:
    print("These sides cannot form a triangle.")
# Out:
# Enter Side 1 of Triangle:  4
# Enter Side 2 of Triangle:  3
# Enter Side 3 of Triangle:  4
# These sides can form a triangle.

# %%
number=int(input("Enter the Number: "))
for i in range(1,11): 
    print(f"{number} X {i}={number*i}")
# Out:
# Enter the Number:  10
# 10 X 1=10
# 10 X 2=20
# 10 X 3=30
# 10 X 4=40
# 10 X 5=50
# 10 X 6=60
# 10 X 7=70
# 10 X 8=80
# 10 X 9=90
# 10 X 10=100

# %%
number=int(input("Enter the 5 Digit Numbers: "))
sum=0
while number>0: 
    digit=number%10
    sum+=digit
    number=number//10

print("Sum of Digit: ",sum)
# Out:
# Enter the 5 Digit Numbers:  12345
# Sum of Digit:  15

# %%
number=int(input("Enter the Number: "))
original=number
reverse=0
while number>0: 
    digit=number%10
    reverse=reverse*10+digit
    number=number//10

if original==reverse:
    print("Number is Palindrome")
else :
    print("Number is Not Palindrome")
# Out:
# Enter the Number:  8888
# Number is Palindrome

# %%
number = int(input("Enter a number: "))

if number <= 1:
    print("Not a Prime Number")
else:
    is_prime = True

    for i in range(2, number):
        if number % i == 0:
            is_prime = False
            break

    if is_prime:
        print("Prime Number")
    else:
        print("Not a Prime Number")
# Out:
# Enter a number:  5
# Prime Number
